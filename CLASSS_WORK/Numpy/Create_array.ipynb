# %% [markdown]
# <a href="https://colab.research.google.com/github/Yash222137/DAVIS_TRAINING/blob/main/CLASSS_WORK/Numpy/Create_array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program to create a numpy array
import numpy as np
# Create a 1D array
numbers = np.array([20,30,40,70,90])
print(numbers)

# Create a 1D array with mixed data types
data = np.array([45, "python", 56])
print(data)
