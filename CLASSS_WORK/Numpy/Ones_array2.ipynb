# %% [markdown]
# <a href="https://colab.research.google.com/github/Yash222137/DAVIS_TRAINING/blob/main/CLASSS_WORK/Numpy/Ones_array2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# to create ones array of order 3,2,5 in int data type

import numpy as np
numbers = np.ones((3,2,5) , dtype=int)
print(numbers)
