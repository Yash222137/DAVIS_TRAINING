# %% [markdown]
# <a href="https://colab.research.google.com/github/Yash222137/DAVIS_TRAINING/blob/main/CLASSS_WORK/Numpy/Zeros_array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# create a zeros array with order 3,6,2 of int data type
import numpy as np
numbers = np.zeros((3,6,2) , dtype=int)
print(numbers)
