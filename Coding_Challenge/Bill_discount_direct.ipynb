# %% [markdown]
# <a href="https://colab.research.google.com/github/Yash222137/DAVIS_TRAINING/blob/main/Coding_Challenge/Bill_discount_direct.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program to calculate discount (direct formula)
# ....................................................................
price = float(input("Enter price: "))
discount = float(input("Enter discount: "))

print(f"Final price after discount: {price*(1-discount/100)}")
# ....................................................................
"""
Output:
Enter price: 500
Enter discount: 10
Final price after discount: 450.0
"""
