# %% [markdown]
# <a href="https://colab.research.google.com/github/Yash222137/DAVIS_TRAINING/blob/main/numericcalculation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#calculation2.py
from numericcalculation import *
m=10
n=20
print("sum of",m,"and",n,"is:",addnumbers(m,n))
print("product of",m,"and",n,"is:",calculateproduct(m,n))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1535/1716871544.py in <cell line: 0>()
#       1 #calculation2.py
# ----> 2 from numericcalculation import *
#       3 m=10
#       4 n=20
#       5 print("sum of",m,"and",n,"is:",addnumbers(m,n))
#
# ModuleNotFoundError: No module named 'numericcalculation'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
